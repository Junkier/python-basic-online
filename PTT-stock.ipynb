8C">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Stock/search?q=author%3AMOMO0478">搜尋看板內 MOMO0478 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/15</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="r-ent">
# 			<div class="nrec"><span class="hl f3">45</span></div>
# 			<div class="title">
#
# 				<a href="/bbs/Stock/M.1644909439.A.2AC.html">[情報] 111年02月15日 櫃買法人買賣金額統計表</a>
#
# 			</div>
# 			<div class="meta">
# 				<div class="author">centaurjr</div>
# 				<div class="article-menu">
#
# 					<div class="trigger">&#x22ef;</div>
# 					<div class="dropdown">
# 						<div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D&#43;111%E5%B9%B402%E6%9C%8815%E6%97%A5&#43;%E6%AB%83%E8%B2%B7%E6%B3%95%E4%BA%BA%E8%B2%B7%E8%B3%A3%E9%87%91%E9%A1%8D%E7%B5%B1%E8%A8%88%E8%A1%A8">搜尋同標題文章</a></div>
#
# 						<div class="item"><a href="/bbs/Stock/search?q=author%3Acentaurjr">搜尋看板內 centaurjr 的文章</a></div>
#
# 					</div>
#
# 				</div>
# 				<div class="date"> 2/15</div>
# 				<div class="mark"></div>
# 			</div>
# 		</div>
#
#
#
# 	</div>
#
#
# </div>
#
#
#
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
#
#     </body>
# </html>

# %%
### 利用 BeautifulSoup 做 html 解析
soup = bs(res.text,"lxml")
data = soup.select("div.r-ent")
# print(data[1])

for ele in data:
    # print(ele)
    title = ele.select("div.title")[0].text.strip()
    print("標題 :" , title)
    print("-"*100)
# Out:
# 標題 : [新聞] 美國確定關閉烏克蘭大使館
# ----------------------------------------------------------------------------------------------------
# 標題 : [新聞] 聯電挫勒但！台積這動作拉客引網友熱議
# ----------------------------------------------------------------------------------------------------
# 標題 : [標的] 2330 台積電 全面做多
# ----------------------------------------------------------------------------------------------------
# 標題 : (已被laptic刪除) <kgbb> 4-2-1 閒聊式提問
# ----------------------------------------------------------------------------------------------------
# 標題 : [新聞] 法國公布國家新核戰略 融資600億建六座新
# ----------------------------------------------------------------------------------------------------
# 標題 : [標的] 1712興農在噴什麼?
# ----------------------------------------------------------------------------------------------------
# 標題 : [新聞] 全球股市震盪 法人：進場勝率8成
# ----------------------------------------------------------------------------------------------------
# 標題 : Re: [標的] 2062.TW 橋椿2021/Q4毛利率上升
# ----------------------------------------------------------------------------------------------------
# 標題 : [新聞] 俄羅斯16日攻入烏克蘭？普丁給答案：願繼續與美國會談
# ----------------------------------------------------------------------------------------------------
# 標題 : [新聞] 六大壽險 元月淨值蒸發2,800億
# ----------------------------------------------------------------------------------------------------
# 標題 : [新聞] 華航貨機降芝加哥擦撞貨櫃嚴重
# ----------------------------------------------------------------------------------------------------
# 標題 : [閒聊] 2022/02/15 盤後閒聊
# ----------------------------------------------------------------------------------------------------
# 標題 : Re: [新聞] 美國確定關閉烏克蘭大使館
# ----------------------------------------------------------------------------------------------------
# 標題 : [心得] 2462 良得電
# ----------------------------------------------------------------------------------------------------
# 標題 : [心得] 友達 一買就跌...
# ----------------------------------------------------------------------------------------------------
# 標題 : [情報] 6104創惟自結12月EPS 0.96
# ----------------------------------------------------------------------------------------------------
# 標題 : [情報] 111年02月15日 三大法人買賣金額統計表
# ----------------------------------------------------------------------------------------------------
# 標題 : Re: [心得] 2462 良得電
# ----------------------------------------------------------------------------------------------------
# 標題 : [情報] 0215上市投信買賣超排行
# ----------------------------------------------------------------------------------------------------
# 標題 : [情報] 111年02月15日 櫃買法人買賣金額統計表
# ----------------------------------------------------------------------------------------------------

# %%
### 解析標題 / 時間 / 推文數量 / 連結
# sample = data[2]

for sample in data:

    # 標題
    title = sample.select("div.title")[0].text.strip()
    # print(sample)
    # print("-"*60)
    
    if "公告" in title or "閒聊" in title: 
        continue
        
    print("標題 :",title)

    # 時間
    time = sample.select("div.date")[0].text.strip()
    print("時間 :" , time)

    # 推文數量
    push_num = sample.select("span.hl")[0].text
    print("推文數量 :",push_num)

    # 連結
    raw_link = sample.select("div.title a")[0]["href"]
    domain_name = "https://www.ptt.cc"
    link = domain_name + raw_link
    print("連結 :" , link)
    
    print("-"*60)
# Out:
# 標題 : [新聞] 美國確定關閉烏克蘭大使館
# 時間 : 2/15
# 推文數量 : 爆
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644895190.A.A5A.html
# ------------------------------------------------------------
# 標題 : [新聞] 聯電挫勒但！台積這動作拉客引網友熱議
# 時間 : 2/15
# 推文數量 : 18
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644895363.A.617.html
# ------------------------------------------------------------
# 標題 : [標的] 2330 台積電 全面做多
# 時間 : 2/15
# 推文數量 : 59
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644895404.A.2EE.html
# ------------------------------------------------------------
# 標題 : [新聞] 法國公布國家新核戰略 融資600億建六座新
# 時間 : 2/15
# 推文數量 : 爆
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644897468.A.4F8.html
# ------------------------------------------------------------
# 標題 : [標的] 1712興農在噴什麼?
# 時間 : 2/15
# 推文數量 : 爆
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644898870.A.B29.html
# ------------------------------------------------------------
# 標題 : [新聞] 全球股市震盪 法人：進場勝率8成
# 時間 : 2/15
# 推文數量 : 36
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644900061.A.B64.html
# ------------------------------------------------------------
# 標題 : Re: [標的] 2062.TW 橋椿2021/Q4毛利率上升
# 時間 : 2/15
# 推文數量 : 4
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644901479.A.DB6.html
# ------------------------------------------------------------
# 標題 : [新聞] 俄羅斯16日攻入烏克蘭？普丁給答案：願繼續與美國會談
# 時間 : 2/15
# 推文數量 : 25
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644904061.A.30B.html
# ------------------------------------------------------------
# 標題 : [新聞] 六大壽險 元月淨值蒸發2,800億
# 時間 : 2/15
# 推文數量 : 4
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644904064.A.CCB.html
# ------------------------------------------------------------
# 標題 : [新聞] 華航貨機降芝加哥擦撞貨櫃嚴重
# 時間 : 2/15
# 推文數量 : 18
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644904310.A.686.html
# ------------------------------------------------------------
# 標題 : Re: [新聞] 美國確定關閉烏克蘭大使館
# 時間 : 2/15
# 推文數量 : 41
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644905578.A.389.html
# ------------------------------------------------------------
# 標題 : [心得] 2462 良得電
# 時間 : 2/15
# 推文數量 : 14
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644905778.A.7A6.html
# ------------------------------------------------------------
# 標題 : [心得] 友達 一買就跌...
# 時間 : 2/15
# 推文數量 : 14
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644907304.A.E50.html
# ------------------------------------------------------------
# 標題 : [情報] 6104創惟自結12月EPS 0.96
# 時間 : 2/15
# 推文數量 : 38
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644907867.A.B99.html
# ------------------------------------------------------------
# 標題 : [情報] 111年02月15日 三大法人買賣金額統計表
# 時間 : 2/15
# 推文數量 : 91
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644908423.A.19C.html
# ------------------------------------------------------------
# 標題 : Re: [心得] 2462 良得電
# 時間 : 2/15
# 推文數量 : 11
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644908706.A.1A1.html
# ------------------------------------------------------------
# 標題 : [情報] 0215上市投信買賣超排行
# 時間 : 2/15
# 推文數量 : 70
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644909253.A.7CB.html
# ------------------------------------------------------------
# 標題 : [情報] 111年02月15日 櫃買法人買賣金額統計表
# 時間 : 2/15
# 推文數量 : 45
# 連結 : https://www.ptt.cc/bbs/Stock/M.1644909439.A.2AC.html
# ------------------------------------------------------------
